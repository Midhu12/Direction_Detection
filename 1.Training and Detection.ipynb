# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\selva\anaconda3\envs\aiml\lib\site-packages (3.2)

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .

# %% [markdown]
# # Install Tensorflow Object Detection
# if os.name=='posix':
#     !apt-get install protobuf-compiler
#     !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install .
#
# if os.name=='nt':
#     url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
#     wget.download(url)
#     !move protoc-3.19.6-win64.zip {paths['PROTOC_PATH']}
#     !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.19.6-win64.zip
#     os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))
#     !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
#     !cd Tensorflow/models/research/slim && pip install -e .

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}

# %%
#!pip install object_detection

# %%
#!pip install PyYAML

# %%
#!pip install matplotlib

# %%
#!pip install protobuf

# %%
#!pip install tensorflow --upgrade

# %%
#!pip uninstall protobuf matplotlib -y
#!pip install protobuf matplotlib==3.2

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ---------------
# absl-py                      2.0.0
# anyio                        4.2.0
# apache-beam                  2.53.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.2.0
# avro-python3                 1.10.2
# Babel                        2.14.0
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# cachetools                   5.3.2
# certifi                      2023.11.17
# cffi                         1.16.0
# charset-normalizer           3.3.2
# colorama                     0.4.6
# comm                         0.2.1
# contextlib2                  21.6.0
# cycler                       0.12.1
# Cython                       3.0.7
# debugpy                      1.8.0
# decorator                    5.1.1
# defusedxml                   0.7.1
# exceptiongroup               1.2.0
# executing                    2.0.1
# fastjsonschema               2.19.1
# flatbuffers                  23.5.26
# fqdn                         1.5.1
# gast                         0.4.0
# gin-config                   0.5.0
# google-auth                  2.26.1
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.60.0
# h5py                         3.10.0
# idna                         3.6
# ipykernel                    6.28.0
# ipython                      8.19.0
# ipywidgets                   8.1.1
# isoduration                  20.11.0
# jedi                         0.19.1
# Jinja2                       3.1.2
# json5                        0.9.14
# jsonpointer                  2.4
# jsonschema                   4.20.0
# jsonschema-specifications    2023.12.1
# jupyter                      1.0.0
# jupyter_client               8.6.0
# jupyter-console              6.6.3
# jupyter_core                 5.7.0
# jupyter-events               0.9.0
# jupyter-lsp                  2.2.1
# jupyter_server               2.12.2
# jupyter_server_terminals     0.5.1
# jupyterlab                   4.0.10
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.25.2
# jupyterlab-widgets           3.0.9
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# kiwisolver                   1.4.5
# libclang                     16.0.6
# lvis                         0.5.3
# lxml                         5.1.0
# Markdown                     3.5.1
# MarkupSafe                   2.1.3
# matplotlib                   3.8.2
# matplotlib-inline            0.1.6
# mistune                      3.0.2
# nbclient                     0.9.0
# nbconvert                    7.14.0
# nbformat                     5.9.2
# nest-asyncio                 1.5.8
# notebook                     7.0.6
# notebook_shim                0.2.3
# numpy                        1.26.3
# oauthlib                     3.2.2
# object-detection             0.1
# opencv-python                4.9.0.80
# opt-einsum                   3.3.0
# overrides                    7.4.0
# packaging                    23.2
# pandas                       2.2.0rc0
# pandocfilters                1.5.0
# parso                        0.8.3
# pillow                       10.2.0
# pip                          23.3.2
# platformdirs                 4.1.0
# portalocker                  2.8.2
# prometheus-client            0.19.0
# prompt-toolkit               3.0.43
# protobuf                     3.19.6
# psutil                       5.9.7
# pure-eval                    0.2.2
# pyasn1                       0.5.1
# pyasn1-modules               0.3.0
# pycocotools                  2.0.7
# pycparser                    2.21
# Pygments                     2.17.2
# pyparsing                    2.4.7
# PyQt5                        5.15.10
# PyQt5-Qt5                    5.15.2
# PyQt5-sip                    12.13.0
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# pytz                         2023.3.post1
# pywin32                      306
# pywinpty                     2.0.12
# PyYAML                       6.0.1
# pyzmq                        25.1.2
# qtconsole                    5.5.1
# QtPy                         2.4.1
# referencing                  0.32.1
# regex                        2023.12.25
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.16.2
# rsa                          4.9
# sacrebleu                    2.2.0
# SciPy                        1.12.0rc1
# Send2Trash                   1.8.2
# setuptools                   68.2.2
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.5
# stack-data                   0.6.3
# tabulate                     0.9.0
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.0
# tensorflow-estimator         2.10.0
# tensorflow-io                0.31.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.4.0
# terminado                    0.18.0
# tf-models-official           2.15.0
# tf-slim                      1.1.0
# tinycss2                     1.2.1
# tomli                        2.0.1
# tornado                      6.4
# traitlets                    5.14.1
# types-python-dateutil        2.8.19.20240106
# typing_extensions            4.9.0
# uri-template                 1.3.0
# urllib3                      2.1.0
# wcwidth                      0.2.13
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.7.0
# Werkzeug                     3.0.1
# wget                         3.2
# wheel                        0.41.2
# widgetsnbextension           4.0.9
# wrapt                        1.16.0

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# 100% [........................................................................] 20515344 / 20515344        1 file(s) moved.
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'Right', 'id':1}, {'name':'Left', 'id':2}, {'name':'Up', 'id':3}, {'name':'Down', 'id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\train.record
# Successfully created the TFRecord file: Tensorflow\workspace\annotations\test.record

# %%
#!pip install pytz

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=6000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=6000

# %%
# !{command}
# Out:
# 2024-01-10 09:20:17.662195: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-01-10 09:20:17.662227: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-01-10 09:20:20.568685: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-01-10 09:20:20.568928: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-01-10 09:20:20.569144: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-01-10 09:20:20.569352: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-01-10 09:20:20.569559: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-01-10 09:20:20.569764: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-01-10 09:20:20.569968: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-01-10 09:20:20.570172: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-01-10 09:20:20.570182: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-01-10 09:20:20.571948: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# W0110 09:20:20.576005 11624 cross_device_ops.py:1387] There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I0110 09:20:20.610385 11624 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 6000
# I0110 09:20:20.613386 11624 config_util.py:552] Maybe overwriting train_steps: 6000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0110 09:20:20.613386 11624 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0110 09:20:20.629385 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# I0110 09:20:20.637460 11624 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# I0110 09:20:20.637460 11624 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0110 09:20:20.637460 11624 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0110 09:20:20.637460 11624 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0110 09:20:20.644973 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0110 09:20:20.657713 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0110 09:20:24.710785 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0110 09:20:27.226243 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0110 09:20:28.934280 11624 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2024-01-10 09:20:31.534154: W tensorflow/core/framework/dataset.cc:769] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0110 09:20:37.117197 13816 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0110 09:20:46.602420  1408 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0110 09:20:54.144557  9796 deprecation.py:554] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0110 09:20:55.352596  9796 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0110 09:21:00.976621 12828 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0110 09:21:06.598420   244 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0110 09:21:12.588057  5932 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# INFO:tensorflow:Step 1100 per-step time 1.205s
# I0110 09:22:54.218423 11624 model_lib_v2.py:705] Step 1100 per-step time 1.205s
# INFO:tensorflow:{'Loss/classification_loss': 0.22333531,
#  'Loss/localization_loss': 0.04840346,
#  'Loss/regularization_loss': 0.15316243,
#  'Loss/total_loss': 0.42490122,
#  'learning_rate': 0.07999918}
# I0110 09:22:54.218423 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.22333531,
#  'Loss/localization_loss': 0.04840346,
#  'Loss/regularization_loss': 0.15316243,
#  'Loss/total_loss': 0.42490122,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.912s
# I0110 09:24:25.366623 11624 model_lib_v2.py:705] Step 1200 per-step time 0.912s
# INFO:tensorflow:{'Loss/classification_loss': 0.20257336,
#  'Loss/localization_loss': 0.11002289,
#  'Loss/regularization_loss': 0.152662,
#  'Loss/total_loss': 0.46525824,
#  'learning_rate': 0.079996705}
# I0110 09:24:25.366623 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.20257336,
#  'Loss/localization_loss': 0.11002289,
#  'Loss/regularization_loss': 0.152662,
#  'Loss/total_loss': 0.46525824,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.912s
# I0110 09:25:56.589851 11624 model_lib_v2.py:705] Step 1300 per-step time 0.912s
# INFO:tensorflow:{'Loss/classification_loss': 0.28954878,
#  'Loss/localization_loss': 0.082061544,
#  'Loss/regularization_loss': 0.15222898,
#  'Loss/total_loss': 0.5238393,
#  'learning_rate': 0.0799926}
# I0110 09:25:56.590886 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.28954878,
#  'Loss/localization_loss': 0.082061544,
#  'Loss/regularization_loss': 0.15222898,
#  'Loss/total_loss': 0.5238393,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.907s
# I0110 09:27:27.309007 11624 model_lib_v2.py:705] Step 1400 per-step time 0.907s
# INFO:tensorflow:{'Loss/classification_loss': 0.14865077,
#  'Loss/localization_loss': 0.07237982,
#  'Loss/regularization_loss': 0.15176754,
#  'Loss/total_loss': 0.37279812,
#  'learning_rate': 0.07998685}
# I0110 09:27:27.310022 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.14865077,
#  'Loss/localization_loss': 0.07237982,
#  'Loss/regularization_loss': 0.15176754,
#  'Loss/total_loss': 0.37279812,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.919s
# I0110 09:28:59.169610 11624 model_lib_v2.py:705] Step 1500 per-step time 0.919s
# INFO:tensorflow:{'Loss/classification_loss': 0.10960534,
#  'Loss/localization_loss': 0.085023925,
#  'Loss/regularization_loss': 0.15126835,
#  'Loss/total_loss': 0.34589761,
#  'learning_rate': 0.07997945}
# I0110 09:28:59.170114 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.10960534,
#  'Loss/localization_loss': 0.085023925,
#  'Loss/regularization_loss': 0.15126835,
#  'Loss/total_loss': 0.34589761,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.919s
# I0110 09:30:31.058000 11624 model_lib_v2.py:705] Step 1600 per-step time 0.919s
# INFO:tensorflow:{'Loss/classification_loss': 0.12386488,
#  'Loss/localization_loss': 0.04264481,
#  'Loss/regularization_loss': 0.1509059,
#  'Loss/total_loss': 0.3174156,
#  'learning_rate': 0.079970405}
# I0110 09:30:31.058000 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.12386488,
#  'Loss/localization_loss': 0.04264481,
#  'Loss/regularization_loss': 0.1509059,
#  'Loss/total_loss': 0.3174156,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.926s
# I0110 09:32:03.623344 11624 model_lib_v2.py:705] Step 1700 per-step time 0.926s
# INFO:tensorflow:{'Loss/classification_loss': 0.18141563,
#  'Loss/localization_loss': 0.14448851,
#  'Loss/regularization_loss': 0.15052843,
#  'Loss/total_loss': 0.47643256,
#  'learning_rate': 0.07995972}
# I0110 09:32:03.623344 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.18141563,
#  'Loss/localization_loss': 0.14448851,
#  'Loss/regularization_loss': 0.15052843,
#  'Loss/total_loss': 0.47643256,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.919s
# I0110 09:33:35.514121 11624 model_lib_v2.py:705] Step 1800 per-step time 0.919s
# INFO:tensorflow:{'Loss/classification_loss': 0.24449176,
#  'Loss/localization_loss': 0.12241543,
#  'Loss/regularization_loss': 0.152055,
#  'Loss/total_loss': 0.51896214,
#  'learning_rate': 0.0799474}
# I0110 09:33:35.514121 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.24449176,
#  'Loss/localization_loss': 0.12241543,
#  'Loss/regularization_loss': 0.152055,
#  'Loss/total_loss': 0.51896214,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.925s
# I0110 09:35:07.986703 11624 model_lib_v2.py:705] Step 1900 per-step time 0.925s
# INFO:tensorflow:{'Loss/classification_loss': 0.15128313,
#  'Loss/localization_loss': 0.09905616,
#  'Loss/regularization_loss': 0.15236418,
#  'Loss/total_loss': 0.40270346,
#  'learning_rate': 0.07993342}
# I0110 09:35:07.986703 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.15128313,
#  'Loss/localization_loss': 0.09905616,
#  'Loss/regularization_loss': 0.15236418,
#  'Loss/total_loss': 0.40270346,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.918s
# I0110 09:36:39.750938 11624 model_lib_v2.py:705] Step 2000 per-step time 0.918s
# INFO:tensorflow:{'Loss/classification_loss': 0.21784581,
#  'Loss/localization_loss': 0.10966854,
#  'Loss/regularization_loss': 0.1519656,
#  'Loss/total_loss': 0.47947997,
#  'learning_rate': 0.07991781}
# I0110 09:36:39.750938 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.21784581,
#  'Loss/localization_loss': 0.10966854,
#  'Loss/regularization_loss': 0.1519656,
#  'Loss/total_loss': 0.47947997,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.930s
# I0110 09:38:12.709498 11624 model_lib_v2.py:705] Step 2100 per-step time 0.930s
# INFO:tensorflow:{'Loss/classification_loss': 0.14861883,
#  'Loss/localization_loss': 0.052851673,
#  'Loss/regularization_loss': 0.15154293,
#  'Loss/total_loss': 0.35301346,
#  'learning_rate': 0.07990056}
# I0110 09:38:12.710546 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.14861883,
#  'Loss/localization_loss': 0.052851673,
#  'Loss/regularization_loss': 0.15154293,
#  'Loss/total_loss': 0.35301346,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.922s
# I0110 09:39:44.867150 11624 model_lib_v2.py:705] Step 2200 per-step time 0.922s
# INFO:tensorflow:{'Loss/classification_loss': 0.13158627,
#  'Loss/localization_loss': 0.102155976,
#  'Loss/regularization_loss': 0.15117662,
#  'Loss/total_loss': 0.38491887,
#  'learning_rate': 0.07988167}
# I0110 09:39:44.867150 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.13158627,
#  'Loss/localization_loss': 0.102155976,
#  'Loss/regularization_loss': 0.15117662,
#  'Loss/total_loss': 0.38491887,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.918s
# I0110 09:41:16.688971 11624 model_lib_v2.py:705] Step 2300 per-step time 0.918s
# INFO:tensorflow:{'Loss/classification_loss': 0.08746068,
#  'Loss/localization_loss': 0.038872734,
#  'Loss/regularization_loss': 0.15070736,
#  'Loss/total_loss': 0.27704078,
#  'learning_rate': 0.07986114}
# I0110 09:41:16.689968 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.08746068,
#  'Loss/localization_loss': 0.038872734,
#  'Loss/regularization_loss': 0.15070736,
#  'Loss/total_loss': 0.27704078,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.924s
# I0110 09:42:49.073730 11624 model_lib_v2.py:705] Step 2400 per-step time 0.924s
# INFO:tensorflow:{'Loss/classification_loss': 0.10195806,
#  'Loss/localization_loss': 0.055922493,
#  'Loss/regularization_loss': 0.1503508,
#  'Loss/total_loss': 0.30823135,
#  'learning_rate': 0.07983897}
# I0110 09:42:49.073730 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.10195806,
#  'Loss/localization_loss': 0.055922493,
#  'Loss/regularization_loss': 0.1503508,
#  'Loss/total_loss': 0.30823135,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.937s
# I0110 09:44:22.812073 11624 model_lib_v2.py:705] Step 2500 per-step time 0.937s
# INFO:tensorflow:{'Loss/classification_loss': 0.0985681,
#  'Loss/localization_loss': 0.0625495,
#  'Loss/regularization_loss': 0.14999068,
#  'Loss/total_loss': 0.3111083,
#  'learning_rate': 0.079815164}
# I0110 09:44:22.812073 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.0985681,
#  'Loss/localization_loss': 0.0625495,
#  'Loss/regularization_loss': 0.14999068,
#  'Loss/total_loss': 0.3111083,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.919s
# I0110 09:45:54.672385 11624 model_lib_v2.py:705] Step 2600 per-step time 0.919s
# INFO:tensorflow:{'Loss/classification_loss': 0.08494136,
#  'Loss/localization_loss': 0.051470723,
#  'Loss/regularization_loss': 0.14942925,
#  'Loss/total_loss': 0.28584135,
#  'learning_rate': 0.07978972}
# I0110 09:45:54.672874 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.08494136,
#  'Loss/localization_loss': 0.051470723,
#  'Loss/regularization_loss': 0.14942925,
#  'Loss/total_loss': 0.28584135,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.906s
# I0110 09:47:25.264017 11624 model_lib_v2.py:705] Step 2700 per-step time 0.906s
# INFO:tensorflow:{'Loss/classification_loss': 0.29822803,
#  'Loss/localization_loss': 0.068968825,
#  'Loss/regularization_loss': 0.1488951,
#  'Loss/total_loss': 0.51609194,
#  'learning_rate': 0.07976264}
# I0110 09:47:25.264017 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.29822803,
#  'Loss/localization_loss': 0.068968825,
#  'Loss/regularization_loss': 0.1488951,
#  'Loss/total_loss': 0.51609194,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.902s
# I0110 09:48:55.482799 11624 model_lib_v2.py:705] Step 2800 per-step time 0.902s
# INFO:tensorflow:{'Loss/classification_loss': 0.124248005,
#  'Loss/localization_loss': 0.08985585,
#  'Loss/regularization_loss': 0.14844732,
#  'Loss/total_loss': 0.36255118,
#  'learning_rate': 0.07973392}
# I0110 09:48:55.482799 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.124248005,
#  'Loss/localization_loss': 0.08985585,
#  'Loss/regularization_loss': 0.14844732,
#  'Loss/total_loss': 0.36255118,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.896s
# I0110 09:50:25.046096 11624 model_lib_v2.py:705] Step 2900 per-step time 0.896s
# INFO:tensorflow:{'Loss/classification_loss': 0.0987754,
#  'Loss/localization_loss': 0.08721266,
#  'Loss/regularization_loss': 0.14788873,
#  'Loss/total_loss': 0.3338768,
#  'learning_rate': 0.07970358}
# I0110 09:50:25.047097 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.0987754,
#  'Loss/localization_loss': 0.08721266,
#  'Loss/regularization_loss': 0.14788873,
#  'Loss/total_loss': 0.3338768,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.895s
# I0110 09:51:54.572830 11624 model_lib_v2.py:705] Step 3000 per-step time 0.895s
# INFO:tensorflow:{'Loss/classification_loss': 0.15383233,
#  'Loss/localization_loss': 0.030647844,
#  'Loss/regularization_loss': 0.14728981,
#  'Loss/total_loss': 0.33177,
#  'learning_rate': 0.0796716}
# I0110 09:51:54.572830 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.15383233,
#  'Loss/localization_loss': 0.030647844,
#  'Loss/regularization_loss': 0.14728981,
#  'Loss/total_loss': 0.33177,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.908s
# I0110 09:53:25.372977 11624 model_lib_v2.py:705] Step 3100 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.16212003,
#  'Loss/localization_loss': 0.06180217,
#  'Loss/regularization_loss': 0.14673677,
#  'Loss/total_loss': 0.370659,
#  'learning_rate': 0.07963799}
# I0110 09:53:25.372977 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.16212003,
#  'Loss/localization_loss': 0.06180217,
#  'Loss/regularization_loss': 0.14673677,
#  'Loss/total_loss': 0.370659,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.899s
# I0110 09:54:55.298561 11624 model_lib_v2.py:705] Step 3200 per-step time 0.899s
# INFO:tensorflow:{'Loss/classification_loss': 0.080689594,
#  'Loss/localization_loss': 0.036434855,
#  'Loss/regularization_loss': 0.14609501,
#  'Loss/total_loss': 0.26321948,
#  'learning_rate': 0.07960275}
# I0110 09:54:55.298561 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.080689594,
#  'Loss/localization_loss': 0.036434855,
#  'Loss/regularization_loss': 0.14609501,
#  'Loss/total_loss': 0.26321948,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.898s
# I0110 09:56:25.123443 11624 model_lib_v2.py:705] Step 3300 per-step time 0.898s
# INFO:tensorflow:{'Loss/classification_loss': 0.06986292,
#  'Loss/localization_loss': 0.03660673,
#  'Loss/regularization_loss': 0.14545083,
#  'Loss/total_loss': 0.25192046,
#  'learning_rate': 0.07956588}
# I0110 09:56:25.123443 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.06986292,
#  'Loss/localization_loss': 0.03660673,
#  'Loss/regularization_loss': 0.14545083,
#  'Loss/total_loss': 0.25192046,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.900s
# I0110 09:57:55.101432 11624 model_lib_v2.py:705] Step 3400 per-step time 0.900s
# INFO:tensorflow:{'Loss/classification_loss': 0.113805614,
#  'Loss/localization_loss': 0.08724594,
#  'Loss/regularization_loss': 0.14552718,
#  'Loss/total_loss': 0.34657875,
#  'learning_rate': 0.079527386}
# I0110 09:57:55.101432 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.113805614,
#  'Loss/localization_loss': 0.08724594,
#  'Loss/regularization_loss': 0.14552718,
#  'Loss/total_loss': 0.34657875,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.898s
# I0110 09:59:24.922538 11624 model_lib_v2.py:705] Step 3500 per-step time 0.898s
# INFO:tensorflow:{'Loss/classification_loss': 0.06827196,
#  'Loss/localization_loss': 0.029673362,
#  'Loss/regularization_loss': 0.14506145,
#  'Loss/total_loss': 0.24300677,
#  'learning_rate': 0.07948727}
# I0110 09:59:24.922538 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.06827196,
#  'Loss/localization_loss': 0.029673362,
#  'Loss/regularization_loss': 0.14506145,
#  'Loss/total_loss': 0.24300677,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.898s
# I0110 10:00:54.764342 11624 model_lib_v2.py:705] Step 3600 per-step time 0.898s
# INFO:tensorflow:{'Loss/classification_loss': 0.0627466,
#  'Loss/localization_loss': 0.03772417,
#  'Loss/regularization_loss': 0.1444575,
#  'Loss/total_loss': 0.24492827,
#  'learning_rate': 0.079445526}
# I0110 10:00:54.764342 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.0627466,
#  'Loss/localization_loss': 0.03772417,
#  'Loss/regularization_loss': 0.1444575,
#  'Loss/total_loss': 0.24492827,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.902s
# I0110 10:02:24.923291 11624 model_lib_v2.py:705] Step 3700 per-step time 0.902s
# INFO:tensorflow:{'Loss/classification_loss': 0.29838973,
#  'Loss/localization_loss': 0.073343076,
#  'Loss/regularization_loss': 0.14420587,
#  'Loss/total_loss': 0.5159387,
#  'learning_rate': 0.07940216}
# I0110 10:02:24.924259 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.29838973,
#  'Loss/localization_loss': 0.073343076,
#  'Loss/regularization_loss': 0.14420587,
#  'Loss/total_loss': 0.5159387,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.902s
# I0110 10:03:55.150037 11624 model_lib_v2.py:705] Step 3800 per-step time 0.902s
# INFO:tensorflow:{'Loss/classification_loss': 0.10283678,
#  'Loss/localization_loss': 0.061171606,
#  'Loss/regularization_loss': 0.14399052,
#  'Loss/total_loss': 0.3079989,
#  'learning_rate': 0.079357184}
# I0110 10:03:55.150037 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.10283678,
#  'Loss/localization_loss': 0.061171606,
#  'Loss/regularization_loss': 0.14399052,
#  'Loss/total_loss': 0.3079989,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.905s
# I0110 10:05:25.620161 11624 model_lib_v2.py:705] Step 3900 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.108217254,
#  'Loss/localization_loss': 0.03488763,
#  'Loss/regularization_loss': 0.14342718,
#  'Loss/total_loss': 0.28653204,
#  'learning_rate': 0.07931058}
# I0110 10:05:25.620161 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.108217254,
#  'Loss/localization_loss': 0.03488763,
#  'Loss/regularization_loss': 0.14342718,
#  'Loss/total_loss': 0.28653204,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.908s
# I0110 10:06:56.383311 11624 model_lib_v2.py:705] Step 4000 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.09650518,
#  'Loss/localization_loss': 0.05779563,
#  'Loss/regularization_loss': 0.14291513,
#  'Loss/total_loss': 0.29721594,
#  'learning_rate': 0.07926236}
# I0110 10:06:56.383311 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.09650518,
#  'Loss/localization_loss': 0.05779563,
#  'Loss/regularization_loss': 0.14291513,
#  'Loss/total_loss': 0.29721594,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.945s
# I0110 10:08:30.862127 11624 model_lib_v2.py:705] Step 4100 per-step time 0.945s
# INFO:tensorflow:{'Loss/classification_loss': 0.07663809,
#  'Loss/localization_loss': 0.0416605,
#  'Loss/regularization_loss': 0.142306,
#  'Loss/total_loss': 0.2606046,
#  'learning_rate': 0.07921253}
# I0110 10:08:30.862127 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.07663809,
#  'Loss/localization_loss': 0.0416605,
#  'Loss/regularization_loss': 0.142306,
#  'Loss/total_loss': 0.2606046,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.942s
# I0110 10:10:05.073647 11624 model_lib_v2.py:705] Step 4200 per-step time 0.942s
# INFO:tensorflow:{'Loss/classification_loss': 0.063637294,
#  'Loss/localization_loss': 0.029038453,
#  'Loss/regularization_loss': 0.1419045,
#  'Loss/total_loss': 0.23458025,
#  'learning_rate': 0.07916109}
# I0110 10:10:05.073647 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.063637294,
#  'Loss/localization_loss': 0.029038453,
#  'Loss/regularization_loss': 0.1419045,
#  'Loss/total_loss': 0.23458025,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.915s
# I0110 10:11:36.606788 11624 model_lib_v2.py:705] Step 4300 per-step time 0.915s
# INFO:tensorflow:{'Loss/classification_loss': 0.069437586,
#  'Loss/localization_loss': 0.024165703,
#  'Loss/regularization_loss': 0.14127699,
#  'Loss/total_loss': 0.23488028,
#  'learning_rate': 0.07910804}
# I0110 10:11:36.606788 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.069437586,
#  'Loss/localization_loss': 0.024165703,
#  'Loss/regularization_loss': 0.14127699,
#  'Loss/total_loss': 0.23488028,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.922s
# I0110 10:13:08.757012 11624 model_lib_v2.py:705] Step 4400 per-step time 0.922s
# INFO:tensorflow:{'Loss/classification_loss': 0.0615081,
#  'Loss/localization_loss': 0.031849984,
#  'Loss/regularization_loss': 0.14074235,
#  'Loss/total_loss': 0.23410043,
#  'learning_rate': 0.07905338}
# I0110 10:13:08.757012 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.0615081,
#  'Loss/localization_loss': 0.031849984,
#  'Loss/regularization_loss': 0.14074235,
#  'Loss/total_loss': 0.23410043,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.909s
# I0110 10:14:39.616381 11624 model_lib_v2.py:705] Step 4500 per-step time 0.909s
# INFO:tensorflow:{'Loss/classification_loss': 0.050388567,
#  'Loss/localization_loss': 0.04214043,
#  'Loss/regularization_loss': 0.14012176,
#  'Loss/total_loss': 0.23265076,
#  'learning_rate': 0.07899711}
# I0110 10:14:39.617269 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.050388567,
#  'Loss/localization_loss': 0.04214043,
#  'Loss/regularization_loss': 0.14012176,
#  'Loss/total_loss': 0.23265076,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.913s
# I0110 10:16:10.867394 11624 model_lib_v2.py:705] Step 4600 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.08047401,
#  'Loss/localization_loss': 0.06536308,
#  'Loss/regularization_loss': 0.1399933,
#  'Loss/total_loss': 0.28583038,
#  'learning_rate': 0.078939244}
# I0110 10:16:10.867394 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.08047401,
#  'Loss/localization_loss': 0.06536308,
#  'Loss/regularization_loss': 0.1399933,
#  'Loss/total_loss': 0.28583038,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.908s
# I0110 10:17:41.687195 11624 model_lib_v2.py:705] Step 4700 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.13577746,
#  'Loss/localization_loss': 0.101291835,
#  'Loss/regularization_loss': 0.13974197,
#  'Loss/total_loss': 0.37681127,
#  'learning_rate': 0.07887978}
# I0110 10:17:41.687195 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.13577746,
#  'Loss/localization_loss': 0.101291835,
#  'Loss/regularization_loss': 0.13974197,
#  'Loss/total_loss': 0.37681127,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.908s
# I0110 10:19:12.489093 11624 model_lib_v2.py:705] Step 4800 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.11348623,
#  'Loss/localization_loss': 0.064705655,
#  'Loss/regularization_loss': 0.1391138,
#  'Loss/total_loss': 0.31730568,
#  'learning_rate': 0.07881871}
# I0110 10:19:12.489093 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.11348623,
#  'Loss/localization_loss': 0.064705655,
#  'Loss/regularization_loss': 0.1391138,
#  'Loss/total_loss': 0.31730568,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.907s
# I0110 10:20:43.172598 11624 model_lib_v2.py:705] Step 4900 per-step time 0.907s
# INFO:tensorflow:{'Loss/classification_loss': 0.11407424,
#  'Loss/localization_loss': 0.03532989,
#  'Loss/regularization_loss': 0.13848548,
#  'Loss/total_loss': 0.2878896,
#  'learning_rate': 0.07875605}
# I0110 10:20:43.172598 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.11407424,
#  'Loss/localization_loss': 0.03532989,
#  'Loss/regularization_loss': 0.13848548,
#  'Loss/total_loss': 0.2878896,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.908s
# I0110 10:22:13.923069 11624 model_lib_v2.py:705] Step 5000 per-step time 0.908s
# INFO:tensorflow:{'Loss/classification_loss': 0.08940214,
#  'Loss/localization_loss': 0.032046493,
#  'Loss/regularization_loss': 0.13792934,
#  'Loss/total_loss': 0.25937796,
#  'learning_rate': 0.078691795}
# I0110 10:22:13.923069 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.08940214,
#  'Loss/localization_loss': 0.032046493,
#  'Loss/regularization_loss': 0.13792934,
#  'Loss/total_loss': 0.25937796,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.909s
# I0110 10:23:44.840978 11624 model_lib_v2.py:705] Step 5100 per-step time 0.909s
# INFO:tensorflow:{'Loss/classification_loss': 0.08868874,
#  'Loss/localization_loss': 0.022386834,
#  'Loss/regularization_loss': 0.13748316,
#  'Loss/total_loss': 0.24855873,
#  'learning_rate': 0.07862595}
# I0110 10:23:44.841922 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.08868874,
#  'Loss/localization_loss': 0.022386834,
#  'Loss/regularization_loss': 0.13748316,
#  'Loss/total_loss': 0.24855873,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.905s
# I0110 10:25:15.352368 11624 model_lib_v2.py:705] Step 5200 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.06047617,
#  'Loss/localization_loss': 0.016949212,
#  'Loss/regularization_loss': 0.13692263,
#  'Loss/total_loss': 0.21434802,
#  'learning_rate': 0.07855851}
# I0110 10:25:15.352368 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.06047617,
#  'Loss/localization_loss': 0.016949212,
#  'Loss/regularization_loss': 0.13692263,
#  'Loss/total_loss': 0.21434802,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.905s
# I0110 10:26:45.821027 11624 model_lib_v2.py:705] Step 5300 per-step time 0.905s
# INFO:tensorflow:{'Loss/classification_loss': 0.048615184,
#  'Loss/localization_loss': 0.03861704,
#  'Loss/regularization_loss': 0.13626982,
#  'Loss/total_loss': 0.22350205,
#  'learning_rate': 0.07848949}
# I0110 10:26:45.821027 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.048615184,
#  'Loss/localization_loss': 0.03861704,
#  'Loss/regularization_loss': 0.13626982,
#  'Loss/total_loss': 0.22350205,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.903s
# I0110 10:28:16.095969 11624 model_lib_v2.py:705] Step 5400 per-step time 0.903s
# INFO:tensorflow:{'Loss/classification_loss': 0.055624057,
#  'Loss/localization_loss': 0.022796612,
#  'Loss/regularization_loss': 0.13569362,
#  'Loss/total_loss': 0.2141143,
#  'learning_rate': 0.078418896}
# I0110 10:28:16.095969 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.055624057,
#  'Loss/localization_loss': 0.022796612,
#  'Loss/regularization_loss': 0.13569362,
#  'Loss/total_loss': 0.2141143,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.901s
# I0110 10:29:46.227245 11624 model_lib_v2.py:705] Step 5500 per-step time 0.901s
# INFO:tensorflow:{'Loss/classification_loss': 0.1764906,
#  'Loss/localization_loss': 0.04893964,
#  'Loss/regularization_loss': 0.13556023,
#  'Loss/total_loss': 0.36099046,
#  'learning_rate': 0.078346714}
# I0110 10:29:46.228245 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.1764906,
#  'Loss/localization_loss': 0.04893964,
#  'Loss/regularization_loss': 0.13556023,
#  'Loss/total_loss': 0.36099046,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.904s
# I0110 10:31:16.631664 11624 model_lib_v2.py:705] Step 5600 per-step time 0.904s
# INFO:tensorflow:{'Loss/classification_loss': 0.078312516,
#  'Loss/localization_loss': 0.053265568,
#  'Loss/regularization_loss': 0.13501473,
#  'Loss/total_loss': 0.2665928,
#  'learning_rate': 0.07827295}
# I0110 10:31:16.631664 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.078312516,
#  'Loss/localization_loss': 0.053265568,
#  'Loss/regularization_loss': 0.13501473,
#  'Loss/total_loss': 0.2665928,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.902s
# I0110 10:32:46.832057 11624 model_lib_v2.py:705] Step 5700 per-step time 0.902s
# INFO:tensorflow:{'Loss/classification_loss': 0.0928051,
#  'Loss/localization_loss': 0.04228985,
#  'Loss/regularization_loss': 0.13445708,
#  'Loss/total_loss': 0.26955205,
#  'learning_rate': 0.07819763}
# I0110 10:32:46.832057 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.0928051,
#  'Loss/localization_loss': 0.04228985,
#  'Loss/regularization_loss': 0.13445708,
#  'Loss/total_loss': 0.26955205,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.904s
# I0110 10:34:17.193386 11624 model_lib_v2.py:705] Step 5800 per-step time 0.904s
# INFO:tensorflow:{'Loss/classification_loss': 0.10351206,
#  'Loss/localization_loss': 0.051010028,
#  'Loss/regularization_loss': 0.13379958,
#  'Loss/total_loss': 0.28832167,
#  'learning_rate': 0.07812072}
# I0110 10:34:17.194391 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.10351206,
#  'Loss/localization_loss': 0.051010028,
#  'Loss/regularization_loss': 0.13379958,
#  'Loss/total_loss': 0.28832167,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.915s
# I0110 10:35:48.702244 11624 model_lib_v2.py:705] Step 5900 per-step time 0.915s
# INFO:tensorflow:{'Loss/classification_loss': 0.04899047,
#  'Loss/localization_loss': 0.02818135,
#  'Loss/regularization_loss': 0.13316636,
#  'Loss/total_loss': 0.21033818,
#  'learning_rate': 0.078042254}
# I0110 10:35:48.703244 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.04899047,
#  'Loss/localization_loss': 0.02818135,
#  'Loss/regularization_loss': 0.13316636,
#  'Loss/total_loss': 0.21033818,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.913s
# I0110 10:37:20.032894 11624 model_lib_v2.py:705] Step 6000 per-step time 0.913s
# INFO:tensorflow:{'Loss/classification_loss': 0.15581535,
#  'Loss/localization_loss': 0.022074772,
#  'Loss/regularization_loss': 0.13254839,
#  'Loss/total_loss': 0.3104385,
#  'learning_rate': 0.07796223}
# I0110 10:37:20.032894 11624 model_lib_v2.py:708] {'Loss/classification_loss': 0.15581535,
#  'Loss/localization_loss': 0.022074772,
#  'Loss/regularization_loss': 0.13254839,
#  'Loss/total_loss': 0.3104385,
#  'learning_rate': 0.07796223}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow\models\research\object_detection\model_main_tf2.py --model_dir=Tensorflow\workspace\models\my_ssd_mobnet --pipeline_config_path=Tensorflow\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=Tensorflow\workspace\models\my_ssd_mobnet

# %%
# !{command}
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.715
# 2024-01-10 10:37:46.697910: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-01-10 10:37:46.697940: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-01-10 10:37:49.559755: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2024-01-10 10:37:49.560018: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2024-01-10 10:37:49.560422: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2024-01-10 10:37:49.560791: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2024-01-10 10:37:49.561146: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2024-01-10 10:37:49.561483: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2024-01-10 10:37:49.561809: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2024-01-10 10:37:49.562125: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2024-01-10 10:37:49.562140: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0110 10:37:49.564063  7232 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0110 10:37:49.565062  7232 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0110 10:37:49.565062  7232 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0110 10:37:49.565062  7232 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0110 10:37:49.565062  7232 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2024-01-10 10:37:49.566857: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# I0110 10:37:49.605827  7232 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# I0110 10:37:49.605827  7232 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow\\workspace\\annotations\\test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0110 10:37:49.605827  7232 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0110 10:37:49.605827  7232 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0110 10:37:49.607823  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0110 10:37:49.616786  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\object_detection-0.1-py3.10.egg\object_detection\builders\dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0110 10:37:51.899889  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0110 10:37:52.572987  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# I0110 10:37:54.131400  7232 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# INFO:tensorflow:Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet\ckpt-7
# I0110 10:37:54.132400  7232 checkpoint_utils.py:151] Found new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet\ckpt-7
# C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0110 10:37:59.553613  7232 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# I0110 10:38:13.822047  7232 api.py:459] feature_map_spatial_dims: [(40, 40), (20, 20), (10, 10), (5, 5), (3, 3)]
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0110 10:38:18.644361  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\util\dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0110 10:38:18.665679  7232 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0110 10:38:18.830260  7232 deprecation.py:350] From C:\Users\SELVA\anaconda3\envs\AIML\lib\site-packages\tensorflow\python\autograph\impl\api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 20 images.
# I0110 10:38:21.530655  7232 coco_evaluation.py:293] Performing evaluation on 20 images.
# INFO:tensorflow:Loading and preparing annotation results...
# I0110 10:38:21.531656  7232 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.00s)
# I0110 10:38:21.532655  7232 coco_tools.py:138] DONE (t=0.00s)
# INFO:tensorflow:Eval metrics at step 6000
# I0110 10:38:21.592045  7232 model_lib_v2.py:1015] Eval metrics at step 6000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.674018
# I0110 10:38:21.598049  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.674018
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# I0110 10:38:21.598049  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.881188
# I0110 10:38:21.599050  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.881188
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): -1.000000
# I0110 10:38:21.599050  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# I0110 10:38:21.599050  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.674018
# I0110 10:38:21.600051  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.674018
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.715000
# I0110 10:38:21.600051  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.715000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.715000
# I0110 10:38:21.600051  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.715000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.715000
# I0110 10:38:21.601049  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.715000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# I0110 10:38:21.601049  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# I0110 10:38:21.601049  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.715000
# I0110 10:38:21.602050  7232 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.715000
# INFO:tensorflow:	+ Loss/localization_loss: 0.092779
# I0110 10:38:21.603050  7232 model_lib_v2.py:1018] 	+ Loss/localization_loss: 0.092779
# INFO:tensorflow:	+ Loss/classification_loss: 0.214983
# I0110 10:38:21.603050  7232 model_lib_v2.py:1018] 	+ Loss/classification_loss: 0.214983
# INFO:tensorflow:	+ Loss/regularization_loss: 0.132543
# I0110 10:38:21.603050  7232 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.132543
# INFO:tensorflow:	+ Loss/total_loss: 0.440305
# I0110 10:38:21.604049  7232 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.440305
# INFO:tensorflow:Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# I0110 10:42:54.137959  7232 checkpoint_utils.py:142] Waiting for new checkpoint at Tensorflow\workspace\models\my_ssd_mobnet
# INFO:tensorflow:Timed-out waiting for a checkpoint.
# I0110 11:42:53.577883  7232 checkpoint_utils.py:205] Timed-out waiting for a checkpoint.

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-7')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Down.488751c8-af04-11ee-94c5-c4d0e336a0b9.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Left.f44e7af0-af03-11ee-84dc-c4d0e336a0b9.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Right.e5ddec63-af03-11ee-a922-c4d0e336a0b9.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'Up.1f9c6115-af04-11ee-9e77-c4d0e336a0b9.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
#!pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)

# %%
# !{command}

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)

# %%
# !{command}

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
